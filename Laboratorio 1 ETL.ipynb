# %% [markdown]
# # Ejercicio ETL 1 basic-Carga

# %%
#algunas librerias importantes

# %%
# Importando las librerias
import pandas as pd
import glob
import os
# Seteamos el directorio a buscar los archivos
path = r'C:/Users/LUIGGI/Desktop/Curso_ETL_Python/ETL DATASET/World Cup/Raw'
#cambiamos el path
os.chdir(path)
files = glob.glob( '*.csv')
print(files)
# Out:
# ['Diciembre_2022.csv', 'Noviembre_2022.csv']

# %%
# Creamos una lista en blanco para cargar los datasets
li = []
# Realizaremos un loop sobre cada archivo, lo leeremos y lo juntaremos.

for f in files:
    # Leemos el archivo
    temp_df = pd.read_csv(f ,sep=';')
    # agregamos a la lista los dataframes
    li.append(temp_df)
    print(f'Dataframe creado exitosamente para {f} con un tamañao {temp_df.shape}')

# Uniremos todos los dataframe en uno
df = pd.concat(li, axis=0)
print(df.shape)
df.head()
# Out:
# Dataframe creado exitosamente para Diciembre_2022.csv con un tamañao (24, 6)
# Dataframe creado exitosamente para Noviembre_2022.csv con un tamañao (40, 6)
# (64, 6)
#                Date           Time            Home      Away Attendance  \
# 0  01 December 2022  18:00 (20:30)          Canada   Morocco     43,102
# 1  01 December 2022  18:00 (20:30)         Croatia   Belgium     43,984
# 2  01 December 2022  22:00 (00:30)     Costa Rica    Germany     67,054
# 3  01 December 2022  22:00 (00:30)           Japan     Spain     44,851
# 4  02 December 2022  18:00 (20:30)  Korea Republic  Portugal     44,097
#
#                            Venue
# 0             Al Thumama Stadium
# 1          Ahmed bin Ali Stadium
# 2                Al Bayt Stadium
# 3  Khalifa International Stadium
# 4         Education City Stadium

# %%
#Pasemos el codigo a un Py

# %% [markdown]
# # Ejercicio ETL 1 Basic-Carga-Mejorado

# %%
#crearemos una funcion para leer solo algunas columnas

def leer_csv(path="",column_name =[] , sep=';'):
    if len(column_name) == 0:
        df = pd.read_csv(path, sep=';')
    else:
        df = pd.read_csv(path,usecols = column_name, sep=';')
    return df

leer_csv(path=files[0] ,column_name =["Date", "Time", "Away"], sep=';')
# Out:
#                 Date           Time            Away
# 0   01 December 2022  18:00 (20:30)         Morocco
# 1   01 December 2022  18:00 (20:30)         Belgium
# 2   01 December 2022  22:00 (00:30)         Germany
# 3   01 December 2022  22:00 (00:30)           Spain
# 4   02 December 2022  18:00 (20:30)        Portugal
# 5   02 December 2022  18:00 (20:30)         Uruguay
# 6   02 December 2022  22:00 (00:30)          Brazil
# 7   02 December 2022  22:00 (00:30)     Switzerland
# 8   03 December 2022  18:00 (20:30)             USA
# 9   03 December 2022  22:00 (00:30)       Australia
# 10  04 December 2022  18:00 (20:30)          Poland
# 11  04 December 2022  22:00 (00:30)         Senegal
# 12  05 December 2022  18:00 (20:30)         Croatia
# 13  05 December 2022  22:00 (00:30)  Korea Republic
# 14  06 December 2022  18:00 (20:30)           Spain
# 15  06 December 2022  22:00 (00:30)     Switzerland
# 16  09 December 2022  18:00 (20:30)          Brazil
# 17  09 December 2022  22:00 (00:30)       Argentina
# 18  10 December 2022  18:00 (20:30)        Portugal
# 19  10 December 2022  22:00 (00:30)          France
# 20  13 December 2022  22:00 (00:30)         Croatia
# 21  14 December 2022  22:00 (00:30)         Morocco
# 22  17 December 2022  18:00 (20:30)         Morocco
# 23  18 December 2022  18:00 (20:30)          France

# %%
# Importando las librerias
import pandas as pd
import glob
import os
# Seteamos el directorio a buscar los archivos
path = r'C:/Users/LUIGGI/Desktop/Curso_ETL_Python/ETL DATASET/World Cup/Raw'
#cambiamos el path
os.chdir(path)
# vamos  a buscar todos los archivos que son csv
files = glob.glob('*.csv')
print(files)
# Out:
# ['Diciembre_2022.csv', 'Noviembre_2022.csv']

# %%
import shutil
# Creamos una lista en blanco para cargar los datasets
li = []
# Realizaremos un loop sobre cada archivo, lo leeremos y lo juntaremos.
path_salida = r'C:/Users/LUIGGI/Desktop/Curso_ETL_Python/ETL DATASET/World Cup/Procesado/'

for f in files:
    # Leemos el archivo
    temp_df = leer_csv(f ,sep=';')
    # agregamos a la lista los dataframes
    li.append(temp_df)
    
    #Moviendo archivos a la capa de Procesado
    shutil.move(f, path_salida+f)

    print(f'Dataframe creado exitosamente para {f} con un tamañao {temp_df.shape}')

# Uniremos todos los dataframe en uno
df = pd.concat(li, axis=0)
print(df.shape)
df.head()
# Out:
# Dataframe creado exitosamente para Diciembre_2022.csv con un tamañao (24, 6)
# Dataframe creado exitosamente para Noviembre_2022.csv con un tamañao (40, 6)
# (64, 6)
#                Date           Time            Home      Away Attendance  \
# 0  01 December 2022  18:00 (20:30)          Canada   Morocco     43,102
# 1  01 December 2022  18:00 (20:30)         Croatia   Belgium     43,984
# 2  01 December 2022  22:00 (00:30)     Costa Rica    Germany     67,054
# 3  01 December 2022  22:00 (00:30)           Japan     Spain     44,851
# 4  02 December 2022  18:00 (20:30)  Korea Republic  Portugal     44,097
#
#                            Venue
# 0             Al Thumama Stadium
# 1          Ahmed bin Ali Stadium
# 2                Al Bayt Stadium
# 3  Khalifa International Stadium
# 4         Education City Stadium

# %%
path_final = r'C:/Users/LUIGGI/Desktop/Curso_ETL_Python/ETL DATASET/World Cup/Consolidado/'

df.to_csv(path_final+"FInal.csv",index=False)

# %% [markdown]
# # Ejercicio ETL 2 Intermedio-Carga

# %% [markdown]
# ### CREANDO SEGMENTACION DE LOS DATOS

# %%
# Importando las librerias
#!pip install openpyxl
import pandas as pd
import glob
# Seteamos el directorio a buscar los archivos
# vamos  a buscar todos los archivos que son csv
path = r'C:\Users\LUIGGI\Desktop\Curso_ETL_Python\ETL DATASET\Dataset_ ventas'
#cambiamos el path
os.chdir(path)
files = glob.glob( '*.xlsx')
print(files)
# Out:
# ['Archivo_procesado.xlsx', 'Consolidado.xlsx', 'Sample - Superstore.xlsx']

# %%
#Cargamos el archivo
df = pd.read_excel(files[2])

# %%
#recorremos por año y por mes
year = df['Order Date'].dt.year.unique()
month = df['Order Date'].dt.month.unique()
#realizamos el cambio de numero por mes 
dic = {1:"Enero", 2:"Febrero", 3:"Marzo", 4:"Abril", 5:"Mayo", 6:"Junio", 7:"Julio", 8:"Agosto", 9:"Septiembre", 10:"Octubre", 11:"Noviembre", 12:"Diciembre"}

# %%
#Realizamos un loop por año y mes
for y in year:
    if not os.path.exists(path+"\\"+str(y)):
            os.mkdir(path+"\\"+str(y))
    for m in month:
        tmp = df[(df['Order Date'].dt.year==y) & (df['Order Date'].dt.month==m) ]
        #Si la ruta no existe la creara
        if not os.path.exists(path+"\\"+str(y)+"\\"+dic.get(m)):
            os.mkdir(path+"\\"+str(y)+"\\"+dic.get(m))
        tmp.to_excel(path+"\\"+str(y)+"\\"+dic.get(m)+"\\"+str(y)+dic.get(m)+".xlsx")

# %% [markdown]
# ### Leyendo los datos de la  subcarpetas

# %%
#!pip install tqdm
import tqdm
procesado = []
archivo_procesado = []
archivo_por_procesar = glob.glob(f'{path}/*/**/*.xlsx', recursive=True)
archivo_por_procesar_final = []
#Leer
archivo = pd.read_excel("Archivo_procesado.xlsx")

# Validamos los archivos que no se han procesado
for x in archivo['Archivo']:
    archivo_por_procesar.remove(x)
    
for x in tqdm.tqdm(archivo_por_procesar):
    tmp = pd.read_excel(x)
    procesado.append( tmp )
    archivo_procesado.append(x)
    
df = pd.concat(procesado, axis = 0) 
df.to_excel("Consolidado.xlsx", index = False)
archivo = pd.DataFrame(archivo_procesado, columns=["Archivo"] )  
archivo.to_excel("Archivo_procesado.xlsx", index = False)
# Out:
# 0it [00:00, ?it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 19
#      16     procesado.append( tmp )
#      17     archivo_procesado.append(x)
# ---> 19 df = pd.concat(procesado, axis = 0)
#      20 df.to_excel("Consolidado.xlsx", index = False)
#      21 archivo = pd.DataFrame(archivo_procesado, columns=["Archivo"] )
#
# File D:\BCP\ALGORTIMO\Curso_ETL_Python\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File D:\BCP\ALGORTIMO\Curso_ETL_Python\lib\site-packages\pandas\core\reshape\concat.py:368, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     146 @deprecate_nonkeyword_arguments(version=None, allowed_args=["objs"])
#     147 def concat(
#     148     objs: Iterable[NDFrame] | Mapping[HashableT, NDFrame],
#    (...)
#     157     copy: bool = True,
#     158 ) -> DataFrame | Series:
#     159     """
#     160     Concatenate pandas objects along a particular axis.
#     161
#    (...)
#     366     1   3   4
#     367     """
# --> 368     op = _Concatenator(
#     369         objs,
#     370         axis=axis,
#     371         ignore_index=ignore_index,
#     372         join=join,
#     373         keys=keys,
#     374         levels=levels,
#     375         names=names,
#     376         verify_integrity=verify_integrity,
#     377         copy=copy,
#     378         sort=sort,
#     379     )
#     381     return op.get_result()
#
# File D:\BCP\ALGORTIMO\Curso_ETL_Python\lib\site-packages\pandas\core\reshape\concat.py:425, in _Concatenator.__init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     422     objs = list(objs)
#     424 if len(objs) == 0:
# --> 425     raise ValueError("No objects to concatenate")
#     427 if keys is None:
#     428     objs = list(com.not_none(*objs))
#
# ValueError: No objects to concatenate

# %% [markdown]
# # Ejercicio ETL 3 Avanzado-Carga SQL- WEB

# %%
#!pip install pyodbc

# %%
#Carga desde SQL
import pyodbc
cnxn = pyodbc.connect(driver='{SQL Server Native Client 11.0}', host='DESKTOP-LPN6KNV\MSQL', database='CLASE',trusted_connection='yes') #, user=uname, password=pword)

# %%
sql = "SELECT * FROM CAMIONES"
data = pd.read_sql(sql, cnxn)
print(data)
# Out:
#    COD_CAMION   MARCA  MODELO  ANNO  PESO_CARGA      PATENTE  VALOR
# 0        1000  susuki  baleno  1995          45      pi-1516  50000
# 1        2000   Mazda     cx3  2021          30      pi-pucp  28000
# 2        3000   TESLA    T100  2022          25  pi-elonmusk  50000
# C:\Users\LUIGGI\AppData\Local\Temp\ipykernel_21712\2087840577.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   data = pd.read_sql(sql, cnxn)

# %%
#Carga desde WEB
#Exploremos el siguiente link
#https://github.com/CSSEGISandData/COVID-19/tree/master/csse_covid_19_data/csse_covid_19_time_series

#importemos la data directamente


#importamos la data

# %%
# Importamos las librerias
from bs4 import BeautifulSoup
import requests
import time
import datetime
import os
import pandas as pd
df = pd.DataFrame()
# Creamos el Bucle infinito
i = 0
while i<10:
    # Capturamos la url 
    url = "https://www.timeanddate.com/weather/peru/lima"

    # Capturamos el hml de la pagina web y creamos un objeto Response
    r  = requests.get(url)
    data = r.text

    # Creamos el objeto soup y le pasamos lo capturado con request
    soup = BeautifulSoup(data, 'lxml')

    # Buscamos el div para sacar los grados
    temp = soup.find_all('div', class_="h2")

    # Buscamos el div para sacar la sensacion termica
    sTerm = soup.find_all('div', class_="clear")
    #Calculamos la fecha del dia de hoy
    fecha = str(datetime.datetime.today())[0:19]
        # Con [0] saco el primer elemento y con [1] el segundo
    print("Fecha: ", str(datetime.datetime.today())[0:19])
    print("La temperatura en Peru: " + temp[0].text)
    print("La sesacion termica: " + sTerm[1].text)
    #unimos las bases de datos
    df = pd.concat([df , pd.DataFrame([[fecha ,temp[0].text,sTerm[1].text]], columns=["Fecha", "Temperatura", "Sensacion termica"])])
    # Tiempo en segundos para ejecutarse nuevamente
    time.sleep(10)

    i +=1
df
# Out:
# Fecha:  2023-01-02 16:40:36
# La temperatura en Peru: 24 °C
# La sesacion termica: 26 °C
# Fecha:  2023-01-02 16:40:46
# La temperatura en Peru: 24 °C
# La sesacion termica: 26 °C
# Fecha:  2023-01-02 16:40:57
# La temperatura en Peru: 24 °C
# La sesacion termica: 26 °C
# Fecha:  2023-01-02 16:41:07
# La temperatura en Peru: 24 °C
# La sesacion termica: 26 °C
# Fecha:  2023-01-02 16:41:17
# La temperatura en Peru: 24 °C
# La sesacion termica: 26 °C
# Fecha:  2023-01-02 16:41:27
# La temperatura en Peru: 24 °C
# La sesacion termica: 26 °C
# Fecha:  2023-01-02 16:41:38
# La temperatura en Peru: 24 °C
# La sesacion termica: 26 °C
# Fecha:  2023-01-02 16:41:48
# La temperatura en Peru: 24 °C
# La sesacion termica: 26 °C
# Fecha:  2023-01-02 16:41:58
# La temperatura en Peru: 24 °C
# La sesacion termica: 26 °C
# Fecha:  2023-01-02 16:42:09
# La temperatura en Peru: 24 °C
# La sesacion termica: 26 °C
#                  Fecha Temperatura Sensacion termica
# 0  2023-01-02 16:40:36       24 °C             26 °C
# 0  2023-01-02 16:40:46       24 °C             26 °C
# 0  2023-01-02 16:40:57       24 °C             26 °C
# 0  2023-01-02 16:41:07       24 °C             26 °C
# 0  2023-01-02 16:41:17       24 °C             26 °C
# 0  2023-01-02 16:41:27       24 °C             26 °C
# 0  2023-01-02 16:41:38       24 °C             26 °C
# 0  2023-01-02 16:41:48       24 °C             26 °C
# 0  2023-01-02 16:41:58       24 °C             26 °C
# 0  2023-01-02 16:42:09       24 °C             26 °C

# %%
df
# Out:
#                  Fecha Temperatura Sensacion termica
# 0  2023-01-02 16:40:36       24 °C             26 °C
# 0  2023-01-02 16:40:46       24 °C             26 °C
# 0  2023-01-02 16:40:57       24 °C             26 °C
# 0  2023-01-02 16:41:07       24 °C             26 °C
# 0  2023-01-02 16:41:17       24 °C             26 °C
# 0  2023-01-02 16:41:27       24 °C             26 °C
# 0  2023-01-02 16:41:38       24 °C             26 °C
# 0  2023-01-02 16:41:48       24 °C             26 °C
# 0  2023-01-02 16:41:58       24 °C             26 °C
# 0  2023-01-02 16:42:09       24 °C             26 °C

# %% [markdown]
# ## TRABAJO FINAL

# %%
#Realizamos un loop por año y mes
#!pip install xlsxwriter
#Codigo Generador de datos
## Este codigo genera el archivo base donde van a trabajar , les dejo el codigo para que lo tengan
path = r'C:\Users\LUIGGI\Desktop\Curso_ETL_Python\ETL DATASET\Tarea carga'
df = pd.read_excel(files[2])
for y in year:
    if not os.path.exists(path+"\\"+str(y)):
            os.mkdir(path+"\\"+str(y))
    writer = pd.ExcelWriter(path+"\\"+str(y)+"\\"+'anual.xlsx', engine='xlsxwriter')
    for m in month:
        tmp_csv = df[(df['Order Date'].dt.year==y) & (df['Order Date'].dt.month==m)&  (df['Data_origen']==0)  ]
        tmp_excel = df[(df['Order Date'].dt.year==y) & (df['Order Date'].dt.month==m)&  (df['Data_origen']==1)  ]
        #Si la ruta no existe la creara
        tmp_excel.to_excel( writer,sheet_name = dic.get(m),index=False)
        tmp_csv.to_csv(path+"\\"+str(y)+"\\"+dic.get(m)+".csv",index=False)
    writer.close()
    
##### Solo cambiar el path del codigo

# %%
## Tips para realizar la tarea

#pista utilice estos codigos para ver los xlsx y los csv , debe utilizar loops para cargar los archivos
glob.glob(f'{path}/*/*.xlsx', recursive=True)
glob.glob(f'{path}/*/*.csv', recursive=True)
# Out:
# ['C:\\Users\\LUIGGI\\Desktop\\Curso_ETL_Python\\ETL DATASET\\Tarea carga\\2014\\Abril.csv',
#  'C:\\Users\\LUIGGI\\Desktop\\Curso_ETL_Python\\ETL DATASET\\Tarea carga\\2014\\Agosto.csv',
#  'C:\\Users\\LUIGGI\\Desktop\\Curso_ETL_Python\\ETL DATASET\\Tarea carga\\2014\\Diciembre.csv',
#  'C:\\Users\\LUIGGI\\Desktop\\Curso_ETL_Python\\ETL DATASET\\Tarea carga\\2014\\Enero.csv',
#  'C:\\Users\\LUIGGI\\Desktop\\Curso_ETL_Python\\ETL DATASET\\Tarea carga\\2014\\Febrero.csv',
#  'C:\\Users\\LUIGGI\\Desktop\\Curso_ETL_Python\\ETL DATASET\\Tarea carga\\2014\\Julio.csv',
#  'C:\\Users\\LUIGGI\\Desktop\\Curso_ETL_Python\\ETL DATASET\\Tarea carga\\2014\\Junio.csv',
#  'C:\\Users\\LUIGGI\\Desktop\\Curso_ETL_Python\\ETL DATASET\\Tarea carga\\2014\\Marzo.csv',
#  'C:\\Users\\LUIGGI\\Desktop\\Curso_ETL_Python\\ETL DATASET\\Tarea carga\\2014\\Mayo.csv',
#  'C:\\Users\\LUIGGI\\Desktop\\Curso_ETL_Python\\ETL DATASET\\Tarea carga\\2014\\Noviembre.csv',
#  'C:\\Users\\LUIGGI\\Desktop\\Curso_ETL_Python\\ETL DATASET\\Tarea carga\\2014\\Octubre.csv',
#  'C:\\Users\\LUIGGI\\Desktop\\Curso_ETL_Python\\ETL DATASET\\Tarea carga\\2014\\Septiembre.csv',
#  'C:\\Users\\LUIGGI\\Desktop\\Curso_ETL_Python\\ETL DATASET\\Tarea carga\\2015\\Abril.csv',
#  'C:\\Users\\LUIGGI\\Desktop\\Curso_ETL_Python\\ETL DATASET\\Tarea carga\\2015\\Agosto.csv',
#  'C:\\Users\\LUIGGI\\Desktop\\Curso_ETL_Python\\ETL DATASET\\Tarea carga\\2015\\Diciembre.csv',
#  'C:\\Users\\LUIGGI\\Desktop\\Curso_ETL_Python\\ETL DATASET\\Tarea carga\\2015\\Enero.csv',
#  'C:\\Users\\LUIGGI\\Desktop\\Curso_ETL_Python\\ETL DATASET\\Tarea carga\\2015\\Febrero.csv',
#  'C:\\Users\\LUIGGI\\Desktop\\Curso_ETL_Python\\ETL DATASET\\Tarea carga\\2015\\Julio.csv',
#  'C:\\Users\\LUIGGI\\Desktop\\Curso_ETL_Python\\ETL DATASET\\Tarea carga\\2015\\Junio.csv',
#  'C:\\Users\\LUIGGI\\Desktop\\Curso_ETL_Python\\ETL DATASET\\Tarea carga\\2015\\Marzo.csv',
#  'C:\\Users\\LUIGGI\\Desktop\\Curso_ETL_Python\\ETL DATASET\\Tarea carga\\2015\\Mayo.csv',
#  'C:\\Users\\LUIGGI\\Desktop\\Curso_ETL_Python\\ETL DATASET\\Tarea carga\\2015\\Noviembre.csv',
#  'C:\\Users\\LUIGGI\\Desktop\\Curso_ETL_Python\\ETL DATASET\\Tarea carga\\2015\\Octubre.csv',
#  'C:\\Users\\LUIGGI\\Desktop\\Curso_ETL_Python\\ETL DATASET\\Tarea carga\\2015\\Septiembre.csv',
#  'C:\\Users\\LUIGGI\\Desktop\\Curso_ETL_Python\\ETL DATASET\\Tarea carga\\2016\\Abril.csv',
#  'C:\\Users\\LUIGGI\\Desktop\\Curso_ETL_Python\\ETL DATASET\\Tarea carga\\2016\\Agosto.csv',
#  'C:\\Users\\LUIGGI\\Desktop\\Curso_ETL_Python\\ETL DATASET\\Tarea carga\\2016\\Diciembre.csv',
#  'C:\\Users\\LUIGGI\\Desktop\\Curso_ETL_Python\\ETL DATASET\\Tarea carga\\2016\\Enero.csv',
#  'C:\\Users\\LUIGGI\\Desktop\\Curso_ETL_Python\\ETL DATASET\\Tarea carga\\2016\\Febrero.csv',
#  'C:\\Users\\LUIGGI\\Desktop\\Curso_ETL_Python\\ETL DATASET\\Tarea carga\\2016\\Julio.csv',
#  'C:\\Users\\LUIGGI\\Desktop\\Curso_ETL_Python\\ETL DATASET\\Tarea carga\\2016\\Junio.csv',
#  'C:\\Users\\LUIGGI\\Desktop\\Curso_ETL_Python\\ETL DATASET\\Tarea carga\\2016\\Marzo.csv',
#  'C:\\Users\\LUIGGI\\Desktop\\Curso_ETL_Python\\ETL DATASET\\Tarea carga\\2016\\Mayo.csv',
#  'C:\\Users\\LUIGGI\\Desktop\\Curso_ETL_Python\\ETL DATASET\\Tarea carga\\2016\\Noviembre.csv',
#  'C:\\Users\\LUIGGI\\Desktop\\Curso_ETL_Python\\ETL DATASET\\Tarea carga\\2016\\Octubre.csv',
#  'C:\\Users\\LUIGGI\\Desktop\\Curso_ETL_Python\\ETL DATASET\\Tarea carga\\2016\\Septiembre.csv',
#  'C:\\Users\\LUIGGI\\Desktop\\Curso_ETL_Python\\ETL DATASET\\Tarea carga\\2017\\Abril.csv',
#  'C:\\Users\\LUIGGI\\Desktop\\Curso_ETL_Python\\ETL DATASET\\Tarea carga\\2017\\Agosto.csv',
#  'C:\\Users\\LUIGGI\\Desktop\\Curso_ETL_Python\\ETL DATASET\\Tarea carga\\2017\\Diciembre.csv',
#  'C:\\Users\\LUIGGI\\Desktop\\Curso_ETL_Python\\ETL DATASET\\Tarea carga\\2017\\Enero.csv',
#  'C:\\Users\\LUIGGI\\Desktop\\Curso_ETL_Python\\ETL DATASET\\Tarea carga\\2017\\Febrero.csv',
#  'C:\\Users\\LUIGGI\\Desktop\\Curso_ETL_Python\\ETL DATASET\\Tarea carga\\2017\\Julio.csv',
#  'C:\\Users\\LUIGGI\\Desktop\\Curso_ETL_Python\\ETL DATASET\\Tarea carga\\2017\\Junio.csv',
#  'C:\\Users\\LUIGGI\\Desktop\\Curso_ETL_Python\\ETL DATASET\\Tarea carga\\2017\\Marzo.csv',
#  'C:\\Users\\LUIGGI\\Desktop\\Curso_ETL_Python\\ETL DATASET\\Tarea carga\\2017\\Mayo.csv',
#  'C:\\Users\\LUIGGI\\Desktop\\Curso_ETL_Python\\ETL DATASET\\Tarea carga\\2017\\Noviembre.csv',
#  'C:\\Users\\LUIGGI\\Desktop\\Curso_ETL_Python\\ETL DATASET\\Tarea carga\\2017\\Octubre.csv',
#  'C:\\Users\\LUIGGI\\Desktop\\Curso_ETL_Python\\ETL DATASET\\Tarea carga\\2017\\Septiembre.csv']

# %%
#tips 2 este codigo permite visualizar las pestañas de cada archivo excel, se debe realizar un loop sobre cada archivo excel
import openpyxl
wb = openpyxl.load_workbook(path +'\\2014\\anual.xlsx')
print(wb.sheetnames)
# Out:
# ['Noviembre', 'Junio', 'Octubre', 'Abril', 'Diciembre', 'Mayo', 'Agosto', 'Julio', 'Septiembre', 'Enero', 'Marzo', 'Febrero']

# %%
#tips 3
# Para cargar una hoja especifica de un excel se debe realizar lo siguiente
tmp = pd.read_excel(path +'\\2014\\anual.xlsx',sheet_name = 'Noviembre' ) 
tmp.head(5)
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0      79  US-2014-147606 2014-11-26 2014-12-01    Second Class    JE-15745
# 1     183  CA-2014-158274 2014-11-19 2014-11-24    Second Class    RM-19675
# 2     184  CA-2014-158274 2014-11-19 2014-11-24    Second Class    RM-19675
# 3     319  CA-2014-164973 2014-11-04 2014-11-09  Standard Class    NM-18445
# 4     320  CA-2014-164973 2014-11-04 2014-11-09  Standard Class    NM-18445
#
#    Customer Name      Segment        Country           City  ...   Region  \
# 0     Joel Eaton     Consumer  United States        Houston  ...  Central
# 1  Robert Marley  Home Office  United States         Monroe  ...    South
# 2  Robert Marley  Home Office  United States         Monroe  ...    South
# 3   Nathan Mautz  Home Office  United States  New York City  ...     East
# 4   Nathan Mautz  Home Office  United States  New York City  ...     East
#
#         Product ID    Category Sub-Category  \
# 0  FUR-FU-10003194   Furniture  Furnishings
# 1  TEC-PH-10003273  Technology       Phones
# 2  TEC-PH-10004896  Technology       Phones
# 3  TEC-MA-10002927  Technology     Machines
# 4  TEC-PH-10004093  Technology       Phones
#
#                                         Product Name    Sales Quantity  \
# 0  Eldon Expressions Desk Accessory, Wood Pencil ...    19.30        5
# 1                                       AT&T TR1909W   503.96        4
# 2                         Nokia Lumia 521 (T-Mobile)   149.95        5
# 3  Canon imageCLASS MF7460 Monochrome Digital Las...  3991.98        2
# 4                                 Panasonic Kx-TS550   275.94        6
#
#    Discount     Profit  Data_origen
# 0       0.6   -14.4750            1
# 1       0.0   131.0296            1
# 2       0.0    41.9860            1
# 3       0.0  1995.9900            1
# 4       0.0    80.0226            1
#
# [5 rows x 22 columns]

# %%
#Debe cargar todos los archivos tanto en csv y en excel y unirlos todo en un solo file
#Deben guardar el archivo final en la carpeta con el nombre consolidado.xlsx

#enviar el codigo final en un word con fotos del proceso.
